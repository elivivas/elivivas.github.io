# %%
import polars as pl

# %%
code_houseing = ["45211200", "45211000", "45211100", "45211300", "45211340"]

raw = pl.read_excel(
    "../data/raw_data/doc_contratos_poder16135_2025.xlsx"
    ).filter(
        pl.col("CPV").str.starts_with(code_houseing[0]) |
        pl.col("CPV").str.starts_with(code_houseing[1]) |
        pl.col("CPV").str.starts_with(code_houseing[2]) |
        pl.col("CPV").str.starts_with(code_houseing[3]) |
        pl.col("CPV").str.starts_with(code_houseing[4]) 
    )
raw
# Out:
# Could not determine dtype for column 10, falling back to string
# Could not determine dtype for column 18, falling back to string
# Could not determine dtype for column 28, falling back to string
# Could not determine dtype for column 32, falling back to string
# Could not determine dtype for column 37, falling back to string
# Could not determine dtype for column 38, falling back to string
# Could not determine dtype for column 39, falling back to string
# Could not determine dtype for column 45, falling back to string
# Could not determine dtype for column 49, falling back to string
# Could not determine dtype for column 50, falling back to string
# Could not determine dtype for column 51, falling back to string
# Could not determine dtype for column 52, falling back to string
# Could not determine dtype for column 53, falling back to string
# Could not determine dtype for column 54, falling back to string
# Could not determine dtype for column 56, falling back to string
# ...
